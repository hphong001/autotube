# %%
# 1. 필수 시스템 도구 및 라이브러리 설치 (1회만 실행)
print("🛠️ 환경 설정 및 패키지 설치 중... (약 1분 소요)")
# !apt-get update -y && apt-get install -y sox libsox-fmt-all > /dev/null
# !pip install -q "qwen-tts" "gradio" "huggingface_hub"
print("✅ 설치가 완료되었습니다! 이제 아래의 [실행기] 셀을 사용하세요.")
# Out:
# 🛠️ 환경 설정 및 패키지 설치 중... (약 1분 소요)
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,703 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.3 MB]
# ...

# %%
#@title 🚀 TTS 서버 실행
모드선택 = "2. 👥 음성 복제 (Voice Clone / Base)" #@param ["1. 🗣️ 프리셋 목소리 (Custom Voice)", "2. 👥 음성 복제 (Voice Clone / Base)", "3. 🎨 목소리 디자인 (Voice Design)"]
import os
from IPython.display import clear_output
clear_output()
print(f"선택하신 [{모드선택}] 모드를 준비합니다...")
print("모델을 메모리에 올리는 중입니다. 약 2~3분 정도 기다려 주세요...\n")
# 선택한 모드에 따라 공식 UI를 각각 최적화하여 띄웁니다.
if "1" in 모드선택:
    # !qwen-tts-demo -c Qwen/Qwen3-TTS-12Hz-1.7B-CustomVoice --dtype float16 --no-flash-attn --share --max-new-tokens 4096
elif "2" in 모드선택:
    # !qwen-tts-demo -c Qwen/Qwen3-TTS-12Hz-1.7B-Base --dtype float16 --no-flash-attn --share --max-new-tokens 4096
elif "3" in 모드선택:
    # !qwen-tts-demo -c Qwen/Qwen3-TTS-12Hz-1.7B-VoiceDesign --dtype float16 --no-flash-attn --share --max-new-tokens 4096
# Out:
# 선택하신 [2. 👥 음성 복제 (Voice Clone / Base)] 모드를 준비합니다...
# 모델을 메모리에 올리는 중입니다. 약 2~3분 정도 기다려 주세요...
#
# 2026-06-04 03:32:04.909308: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ********
# ...
# ********
#
# config.json: 4.49kB [00:00, 2.81MB/s]
# model.safetensors: 100% 3.86G/3.86G [00:44<00:00, 87.3MB/s]
# generation_config.json: 100% 245/245 [00:00<00:00, 2.03MB/s]
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]
# preprocessor_config.json: 100% 234/234 [00:00<00:00, 2.46MB/s]
#
# config.json: 0.00B [00:00, ?B/s]
#
# config.json: 2.34kB [00:00, 2.54MB/s]
# configuration.json: 100% 76.0/76.0 [00:00<00:00, 290kB/s]
# Fetching 4 files:  25% 1/4 [00:00<00:00,  6.40it/s]
# speech_tokenizer/model.safetensors:   0% 0.00/682M [00:00<?, ?B/s]
# ...
